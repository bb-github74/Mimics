# %%
import pandas as pd

# %%
# get cohort patients
cohort_id = pd.read_csv('/Volumes/D/F2023/MIM/mimic_processed/cohort_id.csv', index_col=[0])

# %%
cohort_patients = pd.read_csv('/Volumes/D/F2023/mimic-iv-2.2/hosp/patients.csv')[pd.read_csv('/Volumes/D/F2023/mimic-iv-2.2/hosp/patients.csv').subject_id.isin(cohort_id.subject_id)]

# %%
cohort_patients
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 33        10000980      F          73         2186       2008 - 2010
# 65        10002013      F          53         2156       2008 - 2010
# 103       10002930      F          48         2193       2011 - 2013
# 116       10003400      F          72         2134       2011 - 2013
# 135       10004401      M          82         2141       2008 - 2010
# ...            ...    ...         ...          ...               ...
# 299631    19997293      M          76         2123       2011 - 2013
# 299659    19998330      F          71         2177       2011 - 2013
# 299669    19998591      F          52         2184       2008 - 2010
# 299677    19998878      M          56         2132       2008 - 2010
# 299689    19999287      F          71         2191       2008 - 2010
#
#                dod
# 33      2193-08-26
# 65             NaN
# 103     2201-12-24
# 116     2137-09-02
# 135     2144-06-18
# ...            ...
# 299631  2124-02-20
# 299659  2178-12-08
# 299669  2185-12-05
# 299677  2133-01-03
# 299689  2197-09-02
#
# [11592 rows x 6 columns]

# %%
cohort_admission = pd.read_csv('/Volumes/D/F2023/mimic-iv-2.2/hosp/admissions.csv')[pd.read_csv('/Volumes/D/F2023/mimic-iv-2.2/hosp/admissions.csv').subject_id.isin(cohort_id.subject_id)]

# %%
cohort_admission['admittime'] = pd.to_datetime(cohort_admission['admittime'])
cohort_admission['dischtime'] = pd.to_datetime(cohort_admission['dischtime'])

# %%
def length_of_stay(x):
    difference = x['dischtime'] - x['admittime']
    by_hours = difference.total_seconds() / 3600
    formatted = "{:.2f}".format(by_hours)
    return formatted

# %%
cohort_admission['length_of_stay'] = (cohort_admission.apply(lambda x: length_of_stay(x), axis=1)).astype(float)

# %%
cohort_adm_stay_aggr = cohort_admission.groupby('subject_id').agg(
    num_of_visits = pd.NamedAgg(column='hadm_id', aggfunc='count'),
    total_length_of_stay=pd.NamedAgg(column='length_of_stay', aggfunc='sum')
).reset_index(drop=False)

# %%
cohort_earliest_adm = cohort_admission.groupby('subject_id').agg(
    earliest = pd.NamedAgg(column='admittime', aggfunc='min')
).reset_index(drop=False)
cohort_earliest_adm
# Out:
#        subject_id            earliest
# 0        10000980 2188-01-03 17:41:00
# 1        10002013 2156-06-28 15:53:00
# 2        10002930 2193-08-05 06:18:00
# 3        10003400 2134-06-06 02:25:00
# 4        10004401 2141-06-06 19:20:00
# ...           ...                 ...
# 11587    19997293 2123-10-12 13:46:00
# 11588    19998330 2177-07-25 04:34:00
# 11589    19998591 2185-03-10 14:19:00
# 11590    19998878 2132-03-31 06:39:00
# 11591    19999287 2191-12-29 07:15:00
#
# [11592 rows x 2 columns]

# %%
def earliest_info(dataframe):
    output = []

    # gather unique ID
    pid_list = dataframe.subject_id.unique()

    for pid in pid_list:
        df = dataframe[dataframe.subject_id == pid]
        sorted = df.sort_values('admittime')
        output.append(sorted.head(1)[['subject_id', 'admittime', 'dischtime','deathtime','admission_type', 'admission_location','discharge_location', 'insurance','race']])
    return output

def last_info(dataframe):
    output = []

    # gather unique ID
    pid_list = dataframe.subject_id.unique()

    for pid in pid_list:
        df = dataframe[dataframe.subject_id == pid]
        sorted = df.sort_values('admittime')
        output.append(sorted.tail(1)[['subject_id','admittime', 'dischtime','deathtime','admission_type', 'admission_location','discharge_location', 'insurance','race']])
    return output

# %%
earliest_list = earliest_info(dataframe=cohort_admission)
last_list = last_info(dataframe=cohort_admission)

# %%
pd.concat(earliest_list, axis=0)
# Out:
#         subject_id           admittime           dischtime deathtime  \
# 33        10000980 2188-01-03 17:41:00 2188-01-05 17:30:00       NaN
# 97        10002013 2156-06-28 15:53:00 2156-07-02 15:39:00       NaN
# 152       10002930 2193-08-05 06:18:00 2193-08-05 11:44:00       NaN
# 196       10003400 2134-06-06 02:25:00 2134-06-07 15:05:00       NaN
# 228       10004401 2141-06-06 19:20:00 2141-06-09 12:34:00       NaN
# ...            ...                 ...                 ...       ...
# 431101    19997293 2123-10-12 13:46:00 2123-10-30 15:13:00       NaN
# 431147    19998330 2177-07-25 04:34:00 2177-07-26 14:07:00       NaN
# 431167    19998591 2185-03-10 14:19:00 2185-03-11 14:10:00       NaN
# 431181    19998878 2132-03-31 06:39:00 2132-04-02 16:15:00       NaN
# 431192    19999287 2191-12-29 07:15:00 2192-01-11 19:00:00       NaN
#
#                      admission_type      admission_location  \
# 33                         EW EMER.          EMERGENCY ROOM
# 97                         EW EMER.                    PACU
# 152                  EU OBSERVATION          EMERGENCY ROOM
# 196                        EW EMER.          EMERGENCY ROOM
# 228                        EW EMER.          EMERGENCY ROOM
# ...                             ...                     ...
# 431101                       URGENT  TRANSFER FROM HOSPITAL
# 431147                     EW EMER.          EMERGENCY ROOM
# 431167               EU OBSERVATION          EMERGENCY ROOM
# 431181                     EW EMER.          EMERGENCY ROOM
# 431192  SURGICAL SAME DAY ADMISSION      PHYSICIAN REFERRAL
#
#               discharge_location insurance                    race
# 33              HOME HEALTH CARE  Medicare  BLACK/AFRICAN AMERICAN
# 97                          HOME  Medicaid                   WHITE
# 152                          NaN  Medicare  BLACK/AFRICAN AMERICAN
# 196             HOME HEALTH CARE  Medicare  BLACK/AFRICAN AMERICAN
# 228                         HOME  Medicare                   WHITE
# ...                          ...       ...                     ...
# 431101  SKILLED NURSING FACILITY  Medicare                   WHITE
# 431147          HOME HEALTH CARE  Medicare  BLACK/AFRICAN AMERICAN
# 431167                       NaN     Other                   WHITE
# 431181                      HOME  Medicare                   WHITE
# 431192          HOME HEALTH CARE  Medicare                   WHITE
#
# [11592 rows x 9 columns]

# %%
merged1 = cohort_earliest_adm.merge(pd.concat(earliest_list, axis=0), on='subject_id', how='left')

# %%
merged11 = merged1.merge(pd.concat(last_list, axis=0).drop('race', axis=1), on='subject_id', how='left')
merged11
# Out:
#        subject_id            earliest deathtime_x  \
# 0        10000980 2188-01-03 17:41:00         NaN
# 1        10002013 2156-06-28 15:53:00         NaN
# 2        10002930 2193-08-05 06:18:00         NaN
# 3        10003400 2134-06-06 02:25:00         NaN
# 4        10004401 2141-06-06 19:20:00         NaN
# ...           ...                 ...         ...
# 11587    19997293 2123-10-12 13:46:00         NaN
# 11588    19998330 2177-07-25 04:34:00         NaN
# 11589    19998591 2185-03-10 14:19:00         NaN
# 11590    19998878 2132-03-31 06:39:00         NaN
# 11591    19999287 2191-12-29 07:15:00         NaN
#
#                   admission_type_x    admission_location_x  \
# 0                         EW EMER.          EMERGENCY ROOM
# 1                         EW EMER.                    PACU
# 2                   EU OBSERVATION          EMERGENCY ROOM
# 3                         EW EMER.          EMERGENCY ROOM
# 4                         EW EMER.          EMERGENCY ROOM
# ...                            ...                     ...
# 11587                       URGENT  TRANSFER FROM HOSPITAL
# 11588                     EW EMER.          EMERGENCY ROOM
# 11589               EU OBSERVATION          EMERGENCY ROOM
# 11590                     EW EMER.          EMERGENCY ROOM
# 11591  SURGICAL SAME DAY ADMISSION      PHYSICIAN REFERRAL
#
#            discharge_location_x insurance_x                    race  \
# 0              HOME HEALTH CARE    Medicare  BLACK/AFRICAN AMERICAN
# 1                          HOME    Medicaid                   WHITE
# 2                           NaN    Medicare  BLACK/AFRICAN AMERICAN
# 3              HOME HEALTH CARE    Medicare  BLACK/AFRICAN AMERICAN
# 4                          HOME    Medicare                   WHITE
# ...                         ...         ...                     ...
# 11587  SKILLED NURSING FACILITY    Medicare                   WHITE
# 11588          HOME HEALTH CARE    Medicare  BLACK/AFRICAN AMERICAN
# 11589                       NaN       Other                   WHITE
# 11590                      HOME    Medicare                   WHITE
# 11591          HOME HEALTH CARE    Medicare                   WHITE
#
#                 admittime           dischtime          deathtime_y  \
# 0     2193-08-15 01:01:00 2193-08-17 15:07:00                  NaN
# 1     2167-07-05 06:10:00 2167-07-05 11:44:00                  NaN
# 2     2201-03-23 19:15:00 2201-03-26 14:24:00                  NaN
# 3     2137-08-04 00:07:00 2137-09-02 17:05:00  2137-09-02 17:05:00
# 4     2144-06-05 19:45:00 2144-06-18 21:30:00  2144-06-18 21:30:00
# ...                   ...                 ...                  ...
# 11587 2123-12-29 01:47:00 2124-01-10 16:30:00                  NaN
# 11588 2178-11-27 21:51:00 2178-12-01 17:10:00                  NaN
# 11589 2185-07-03 20:20:00 2185-08-03 14:42:00                  NaN
# 11590 2132-12-20 06:00:00 2132-12-26 13:45:00                  NaN
# 11591 2197-08-03 20:58:00 2197-08-18 15:37:00                  NaN
#
#         admission_type_y    admission_location_y  \
# 0      OBSERVATION ADMIT   WALK-IN/SELF REFERRAL
# 1         EU OBSERVATION      PHYSICIAN REFERRAL
# 2         EU OBSERVATION      PHYSICIAN REFERRAL
# 3                 URGENT  TRANSFER FROM HOSPITAL
# 4               EW EMER.          EMERGENCY ROOM
# ...                  ...                     ...
# 11587             URGENT  TRANSFER FROM HOSPITAL
# 11588           EW EMER.          EMERGENCY ROOM
# 11589           EW EMER.          EMERGENCY ROOM
# 11590           EW EMER.          EMERGENCY ROOM
# 11591           EW EMER.          EMERGENCY ROOM
#
#                discharge_location_y insurance_y
# 0                  HOME HEALTH CARE       Other
# 1                               NaN       Other
# 2                               NaN    Medicare
# 3                              DIED    Medicare
# 4                              DIED    Medicare
# ...                             ...         ...
# 11587  CHRONIC/LONG TERM ACUTE CARE    Medicare
# 11588              HOME HEALTH CARE       Other
# 11589                         REHAB    Medicare
# 11590              HOME HEALTH CARE    Medicare
# 11591                       HOSPICE    Medicare
#
# [11592 rows x 15 columns]

# %%
merged2 = merged11.merge(cohort_adm_stay_aggr, on='subject_id',how='left')

# %%
merged3 = cohort_patients.merge(merged2, on='subject_id', how='left')

# %%
merged3[['deathtime_x','deathtime_y']]
# Out:
#       deathtime_x          deathtime_y
# 0             NaN                  NaN
# 1             NaN                  NaN
# 2             NaN                  NaN
# 3             NaN  2137-09-02 17:05:00
# 4             NaN  2144-06-18 21:30:00
# ...           ...                  ...
# 11587         NaN                  NaN
# 11588         NaN                  NaN
# 11589         NaN                  NaN
# 11590         NaN                  NaN
# 11591         NaN                  NaN
#
# [11592 rows x 2 columns]

# %%
merged3.columns = ['subject_id', 'gender', 'anchor_age', 'anchor_year',
                    'anchor_year_group', 'dod', 'earliest', 'deathtime_x',
                    'admission_type_x', 'admission_location_x', 'discharge_location_x',
                    'insurance_x', 'race', 'admittime_y', 'dischtime_y', 'deathtime_y','admission_type_y', 'admission_location_y', 'discharge_location_y','insurance_y', 'num_of_visits', 'total_length_of_stay']

# %%
merged3
# Out:
#        subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0        10000980      F          73         2186       2008 - 2010
# 1        10002013      F          53         2156       2008 - 2010
# 2        10002930      F          48         2193       2011 - 2013
# 3        10003400      F          72         2134       2011 - 2013
# 4        10004401      M          82         2141       2008 - 2010
# ...           ...    ...         ...          ...               ...
# 11587    19997293      M          76         2123       2011 - 2013
# 11588    19998330      F          71         2177       2011 - 2013
# 11589    19998591      F          52         2184       2008 - 2010
# 11590    19998878      M          56         2132       2008 - 2010
# 11591    19999287      F          71         2191       2008 - 2010
#
#               dod            earliest deathtime_x  \
# 0      2193-08-26 2188-01-03 17:41:00         NaN
# 1             NaN 2156-06-28 15:53:00         NaN
# 2      2201-12-24 2193-08-05 06:18:00         NaN
# 3      2137-09-02 2134-06-06 02:25:00         NaN
# 4      2144-06-18 2141-06-06 19:20:00         NaN
# ...           ...                 ...         ...
# 11587  2124-02-20 2123-10-12 13:46:00         NaN
# 11588  2178-12-08 2177-07-25 04:34:00         NaN
# 11589  2185-12-05 2185-03-10 14:19:00         NaN
# 11590  2133-01-03 2132-03-31 06:39:00         NaN
# 11591  2197-09-02 2191-12-29 07:15:00         NaN
#
#                   admission_type_x    admission_location_x  ...  \
# 0                         EW EMER.          EMERGENCY ROOM  ...
# 1                         EW EMER.                    PACU  ...
# 2                   EU OBSERVATION          EMERGENCY ROOM  ...
# 3                         EW EMER.          EMERGENCY ROOM  ...
# 4                         EW EMER.          EMERGENCY ROOM  ...
# ...                            ...                     ...  ...
# 11587                       URGENT  TRANSFER FROM HOSPITAL  ...
# 11588                     EW EMER.          EMERGENCY ROOM  ...
# 11589               EU OBSERVATION          EMERGENCY ROOM  ...
# 11590                     EW EMER.          EMERGENCY ROOM  ...
# 11591  SURGICAL SAME DAY ADMISSION      PHYSICIAN REFERRAL  ...
#
#                          race         admittime_y         dischtime_y  \
# 0      BLACK/AFRICAN AMERICAN 2193-08-15 01:01:00 2193-08-17 15:07:00
# 1                       WHITE 2167-07-05 06:10:00 2167-07-05 11:44:00
# 2      BLACK/AFRICAN AMERICAN 2201-03-23 19:15:00 2201-03-26 14:24:00
# 3      BLACK/AFRICAN AMERICAN 2137-08-04 00:07:00 2137-09-02 17:05:00
# 4                       WHITE 2144-06-05 19:45:00 2144-06-18 21:30:00
# ...                       ...                 ...                 ...
# 11587                   WHITE 2123-12-29 01:47:00 2124-01-10 16:30:00
# 11588  BLACK/AFRICAN AMERICAN 2178-11-27 21:51:00 2178-12-01 17:10:00
# 11589                   WHITE 2185-07-03 20:20:00 2185-08-03 14:42:00
# 11590                   WHITE 2132-12-20 06:00:00 2132-12-26 13:45:00
# 11591                   WHITE 2197-08-03 20:58:00 2197-08-18 15:37:00
#
#                deathtime_y   admission_type_y    admission_location_y  \
# 0                      NaN  OBSERVATION ADMIT   WALK-IN/SELF REFERRAL
# 1                      NaN     EU OBSERVATION      PHYSICIAN REFERRAL
# 2                      NaN     EU OBSERVATION      PHYSICIAN REFERRAL
# 3      2137-09-02 17:05:00             URGENT  TRANSFER FROM HOSPITAL
# 4      2144-06-18 21:30:00           EW EMER.          EMERGENCY ROOM
# ...                    ...                ...                     ...
# 11587                  NaN             URGENT  TRANSFER FROM HOSPITAL
# 11588                  NaN           EW EMER.          EMERGENCY ROOM
# 11589                  NaN           EW EMER.          EMERGENCY ROOM
# 11590                  NaN           EW EMER.          EMERGENCY ROOM
# 11591                  NaN           EW EMER.          EMERGENCY ROOM
#
#                discharge_location_y insurance_y num_of_visits  \
# 0                  HOME HEALTH CARE       Other             7
# 1                               NaN       Other            12
# 2                               NaN    Medicare            12
# 3                              DIED    Medicare             7
# 4                              DIED    Medicare            12
# ...                             ...         ...           ...
# 11587  CHRONIC/LONG TERM ACUTE CARE    Medicare             4
# 11588              HOME HEALTH CARE       Other             6
# 11589                         REHAB    Medicare             2
# 11590              HOME HEALTH CARE    Medicare             6
# 11591                       HOSPICE    Medicare             3
#
#       total_length_of_stay
# 0                   578.24
# 1                   943.30
# 2                   958.43
# 3                  1971.83
# 4                  1626.97
# ...                    ...
# 11587              1053.64
# 11588               589.91
# 11589               762.22
# 11590               521.47
# 11591               808.92
#
# [11592 rows x 22 columns]

# %%
cohort_race_ml = cohort_admission[['subject_id', 'race', 'length_of_stay']].pivot_table(index='subject_id', columns='race', aggfunc='count', fill_value=0).reset_index(drop=False)

# %%
cohort_admission.race.value_counts()
# Out:
# race
# WHITE                                        39291
# BLACK/AFRICAN AMERICAN                       13530
# OTHER                                         1691
# HISPANIC/LATINO - PUERTO RICAN                1593
# HISPANIC OR LATINO                            1593
# WHITE - RUSSIAN                               1117
# UNKNOWN                                       1037
# WHITE - OTHER EUROPEAN                         747
# ASIAN - CHINESE                                640
# HISPANIC/LATINO - DOMINICAN                    625
# BLACK/CAPE VERDEAN                             600
# BLACK/CARIBBEAN ISLAND                         597
# ASIAN                                          534
# PORTUGUESE                                     425
# UNABLE TO OBTAIN                               320
# BLACK/AFRICAN                                  317
# ASIAN - SOUTH EAST ASIAN                       312
# HISPANIC/LATINO - GUATEMALAN                   207
# PATIENT DECLINED TO ANSWER                     191
# ASIAN - ASIAN INDIAN                           186
# AMERICAN INDIAN/ALASKA NATIVE                  127
# WHITE - EASTERN EUROPEAN                       123
# HISPANIC/LATINO - SALVADORAN                   108
# HISPANIC/LATINO - CUBAN                        105
# HISPANIC/LATINO - CENTRAL AMERICAN              78
# MULTIPLE RACE/ETHNICITY                         72
# SOUTH AMERICAN                                  70
# HISPANIC/LATINO - HONDURAN                      62
# HISPANIC/LATINO - COLUMBIAN                     56
# WHITE - BRAZILIAN                               54
# HISPANIC/LATINO - MEXICAN                       39
# ASIAN - KOREAN                                  35
# NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER       14
# Name: count, dtype: int64

# %%
cohort_admission
# Out:
#         subject_id   hadm_id           admittime           dischtime  \
# 28        10000980  20897796 2193-08-15 01:01:00 2193-08-17 15:07:00
# 29        10000980  24947999 2190-11-06 20:57:00 2190-11-08 15:58:00
# 30        10000980  25242409 2191-04-03 18:48:00 2191-04-11 16:21:00
# 31        10000980  25911675 2191-05-23 15:33:00 2191-05-24 17:14:00
# 32        10000980  26913865 2189-06-27 07:38:00 2189-07-03 03:00:00
# ...            ...       ...                 ...                 ...
# 431182    19998878  27930413 2132-05-23 16:10:00 2132-05-27 19:00:00
# 431183    19998878  29356037 2132-08-17 20:59:00 2132-08-23 14:00:00
# 431190    19999287  20175828 2197-08-03 20:58:00 2197-08-18 15:37:00
# 431191    19999287  22997012 2197-07-26 03:29:00 2197-07-31 14:00:00
# 431192    19999287  25875727 2191-12-29 07:15:00 2192-01-11 19:00:00
#
#        deathtime               admission_type admit_provider_id  \
# 28           NaN            OBSERVATION ADMIT            P77SO2
# 29           NaN                     EW EMER.            P434W4
# 30           NaN                     EW EMER.            P33K8A
# 31           NaN                     EW EMER.            P29CGZ
# 32           NaN                     EW EMER.            P30KEH
# ...          ...                          ...               ...
# 431182       NaN                     EW EMER.            P30KEH
# 431183       NaN                     EW EMER.            P60CC5
# 431190       NaN                     EW EMER.            P039RH
# 431191       NaN                     EW EMER.            P44WVR
# 431192       NaN  SURGICAL SAME DAY ADMISSION            P12HNH
#
#            admission_location        discharge_location insurance language  \
# 28      WALK-IN/SELF REFERRAL          HOME HEALTH CARE     Other  ENGLISH
# 29             EMERGENCY ROOM          HOME HEALTH CARE  Medicare  ENGLISH
# 30             EMERGENCY ROOM  SKILLED NURSING FACILITY  Medicare  ENGLISH
# 31             EMERGENCY ROOM          HOME HEALTH CARE  Medicare  ENGLISH
# 32             EMERGENCY ROOM          HOME HEALTH CARE  Medicare  ENGLISH
# ...                       ...                       ...       ...      ...
# 431182         EMERGENCY ROOM                      HOME  Medicare  ENGLISH
# 431183         EMERGENCY ROOM          HOME HEALTH CARE  Medicare  ENGLISH
# 431190         EMERGENCY ROOM                   HOSPICE  Medicare  ENGLISH
# 431191         EMERGENCY ROOM          HOME HEALTH CARE  Medicare  ENGLISH
# 431192     PHYSICIAN REFERRAL          HOME HEALTH CARE  Medicare  ENGLISH
#
#        marital_status                    race            edregtime  \
# 28            MARRIED  BLACK/AFRICAN AMERICAN  2193-08-14 21:25:00
# 29            MARRIED  BLACK/AFRICAN AMERICAN  2190-11-06 15:30:00
# 30            MARRIED  BLACK/AFRICAN AMERICAN  2191-04-03 12:36:00
# 31            MARRIED  BLACK/AFRICAN AMERICAN  2191-05-22 16:06:00
# 32            MARRIED  BLACK/AFRICAN AMERICAN  2189-06-27 06:25:00
# ...               ...                     ...                  ...
# 431182         SINGLE                   WHITE  2132-05-23 14:30:00
# 431183         SINGLE                   WHITE  2132-08-17 14:32:00
# 431190         SINGLE  BLACK/AFRICAN AMERICAN  2197-08-03 19:34:00
# 431191         SINGLE  BLACK/AFRICAN AMERICAN  2197-07-26 02:51:00
# 431192         SINGLE                   WHITE                  NaN
#
#                   edouttime  hospital_expire_flag  length_of_stay
# 28      2193-08-15 02:22:00                     0           62.10
# 29      2190-11-06 23:16:00                     0           43.02
# 30      2191-04-03 20:29:00                     0          189.55
# 31      2191-05-23 17:56:00                     0           25.68
# 32      2189-06-27 08:42:00                     0          139.37
# ...                     ...                   ...             ...
# 431182  2132-05-23 17:51:00                     0           98.83
# 431183  2132-08-17 21:33:00                     0          137.02
# 431190  2197-08-04 00:02:00                     0          354.65
# 431191  2197-07-26 05:00:00                     0          130.52
# 431192                  NaN                     0          323.75
#
# [66496 rows x 17 columns]
